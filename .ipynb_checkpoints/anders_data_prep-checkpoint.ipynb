# %% [markdown]
# # Feature Engineering

# %% [markdown]
# IMDb, acronym for Internet Movie Database, is a website owned by Amazon.com where users can look for details about movies and TV shows: plot summaries, users reviews, genre, director and cast are just some of the attributes stored on IMDb.
#
# The goal of this project is to predict the rating of a given movie using properly trained Machine Learning models and evaluate the goodness of the predictions.
# The chosen dataset was made available on the Kaggle platform and it contains the top 100 movies between 2003 - 2022.
#
# Dataset: https://www.kaggle.com/datasets/georgescutelnicu/top-100-popular-movies-from-2003-to-2022-imdb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import cpi

# %% [markdown]
# ## 1. Understanding the Data

# %%
dataset_raw = pd.read_csv('movies.csv')
dataset_raw.head(2)
# Out:
#                             Title  Rating  Year     Month Certificate Runtime  \
# 0        Avatar: The Way of Water     7.8  2022  December       PG-13     192
# 1  Guillermo del Toro's Pinocchio     7.6  2022  December          PG     117
#
#                             Directors  \
# 0                       James Cameron
# 1  Guillermo del Toro, Mark Gustafson
#
#                                                Stars  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1  Ewan McGregor, David Bradley, Gregory Mann, Bu...
#
#                         Genre Filming_location         Budget  \
# 0  Action, Adventure, Fantasy      New Zealand  $350,000,000
# 1    Animation, Drama, Family              USA   $35,000,000
#
#             Income              Country_of_origin
# 0  $2,267,946,983                   United States
# 1        $108,967   United States, Mexico, France

# %% [markdown]
# ### 3.4. Budget & Income: Turning into USD currency (VEDA)

# %%
dataset_processed_finance = dataset_raw

# Checking for how the finance data looks
budget_values = dataset_processed_finance['Budget'].unique()
income_values = dataset_processed_finance['Income'].unique()

#print(f'Budget values: {budget_values}')
#print(f'Income values: {income_values}')

'''There are unconsistencies in how the values are writen, extra 
# spaces etc. Also presence of 'Unknown'''

# 2. Getting number of movies with uknown runtime
unknown_budget_currency = dataset_processed_finance['Budget'].value_counts()['Unknown']
unknown_income_currency = dataset_processed_finance['Income'].value_counts()['Unknown']

missing_budget_values = dataset_processed_finance['Budget'].isnull().sum()
missing_income_values = dataset_processed_finance['Income'].isnull().sum()

print(f'Number of movies with unknown budget: {unknown_budget_currency}')
print(f'Number of movies with empty budget: {missing_budget_values}')
print(f'Number of movies with unknown income: {unknown_income_currency}')
print(f'Number of movies with empty budget: {missing_income_values}')
# Out:
# Number of movies with unknown budget: 304
# Number of movies with empty budget: 0
# Number of movies with unknown income: 145
# Number of movies with empty budget: 0

# %%
# 3. Dropping all movies without a budget
dataset_processed_finance = dataset_processed_finance.drop(dataset_processed_finance[dataset_processed_finance['Budget'].isin(['Unknown'])].index)

# 4. Checking the dataset shape
print('-----------------------------')
print(f'Current number of columns (Budget): {dataset_processed_finance.shape[1]}')
print(f'Current number of rows (Budget): {dataset_processed_finance.shape[0]}')


# 5. Dropping all movies without a income
dataset_processed_finance = dataset_processed_finance.drop(dataset_processed_finance[dataset_processed_finance['Income'].isin(['Unknown'])].index)

# 6. Checking the dataset shape
print('-----------------------------')
print(f'Current number of columns (Income): {dataset_processed_finance.shape[1]}')
print(f'Current number of rows (Income): {dataset_processed_finance.shape[0]}')
# Out:
# -----------------------------
# Current number of columns (Budget): 13
# Current number of rows (Budget): 1696
# -----------------------------
# Current number of columns (Income): 13
# Current number of rows (Income): 1651

# %%
# Conversion function (converts currency and to float)
def convert_to_usd(amount):
    amount.replace(' ', '')
    amount.replace('\xa0', '')
    if amount.startswith('$'):
        amount = amount.strip('$').replace(',', '')   # must remove commas
        return float(amount)   # convert str into float
    elif amount.startswith('€'):
        # Exchange rate for EUR to USD
        amount = amount.strip('€').replace(',', '')
        return float(amount) * 1.06 
    elif amount.startswith('¥'):
        # Exchange rate for YEN to USD
        amount = amount.strip('¥').replace(',', '')
        return float(amount) * 0.0075
    elif amount.startswith('₹'):
        # Exchange rate for RPL to USD
        amount = amount.strip('₹').replace(',', '')
        return float(amount) * 0.012 
    elif amount.startswith('SEK'):
        # Exchange rate for SEK to USD
        amount = amount.strip('SEK').replace(',', '')
        return float(amount) * 0.094
    elif amount.startswith('DKK'):
        # Exchange rate for RPL to USD
        amount = amount.strip('DKK').replace(',', '')
        return float(amount) * 0.14
    elif amount.startswith('£'):
        # Exchange rate for RPL to USD
        amount = amount.strip('£').replace(',', '')
        return float(amount) * 1.21  
    else:
        return None

# %%
# 7. Applying the conversion function
dataset_processed_finance['Budget'] = dataset_processed_finance['Budget'].apply(convert_to_usd)
dataset_processed_finance['Income'] = dataset_processed_finance['Income'].apply(convert_to_usd)

dataset_processed_finance.info()  # 9 missing values in Budget
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1651 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1651 non-null   object
#  1   Rating             1651 non-null   float64
#  2   Year               1651 non-null   int64
#  3   Month              1651 non-null   object
#  4   Certificate        1646 non-null   object
#  5   Runtime            1651 non-null   object
#  6   Directors          1651 non-null   object
#  7   Stars              1651 non-null   object
#  8   Genre              1651 non-null   object
#  9   Filming_location   1651 non-null   object
#  10  Budget             1642 non-null   float64
#  11  Income             1651 non-null   float64
#  12  Country_of_origin  1651 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 180.6+ KB

# %%
# 8. Removing 9 titles with empty budget values 
dataset_processed_finance = dataset_processed_finance.dropna(axis=0, subset=['Budget'])

# 9. Checking the dataset shape
print('-----------------------------')
print(f'Current number of columns: {dataset_processed_finance.shape[1]}')
print(f'Current number of rows: {dataset_processed_finance.shape[0]}')
# Out:
# -----------------------------
# Current number of columns: 13
# Current number of rows: 1642

# %%
dataset_processed_1 = dataset_processed_finance

# %%
dataset_processed_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1642 entries, 0 to 1999
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Title              1642 non-null   object
#  1   Rating             1642 non-null   float64
#  2   Year               1642 non-null   int64
#  3   Month              1642 non-null   object
#  4   Certificate        1637 non-null   object
#  5   Runtime            1642 non-null   object
#  6   Directors          1642 non-null   object
#  7   Stars              1642 non-null   object
#  8   Genre              1642 non-null   object
#  9   Filming_location   1642 non-null   object
#  10  Budget             1642 non-null   float64
#  11  Income             1642 non-null   float64
#  12  Country_of_origin  1642 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 179.6+ KB

# %%
dataset_processed_1.head()
# Out:
#                             Title  Rating  Year     Month Certificate Runtime  \
# 0        Avatar: The Way of Water     7.8  2022  December       PG-13     192
# 1  Guillermo del Toro's Pinocchio     7.6  2022  December          PG     117
# 2                    Bullet Train     7.3  2022    August           R     127
# 4                           M3gan     6.4  2022  December       PG-13     102
# 6                       Amsterdam     6.1  2022   October           R     134
#
#                             Directors  \
# 0                       James Cameron
# 1  Guillermo del Toro, Mark Gustafson
# 2                        David Leitch
# 4                    Gerard Johnstone
# 6                     David O Russell
#
#                                                Stars  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1  Ewan McGregor, David Bradley, Gregory Mann, Bu...
# 2  Brad Pitt, Joey King, Aaron Taylor Johnson, Br...
# 4  Jenna Davis, Amie Donald, Allison Williams, Vi...
# 6  Christian Bale, Margot Robbie, John David Wash...
#
#                         Genre Filming_location       Budget        Income  \
# 0  Action, Adventure, Fantasy      New Zealand  350000000.0  2.267947e+09
# 1    Animation, Drama, Family              USA   35000000.0  1.089670e+05
# 2    Action, Comedy, Thriller            Japan   85900000.0  2.392686e+08
# 4    Horror, Sci-Fi, Thriller      New Zealand   12000000.0  1.712539e+08
# 6      Comedy, Drama, History              USA   80000000.0  3.124581e+07
#
#                Country_of_origin
# 0                  United States
# 1  United States, Mexico, France
# 2           Japan, United States
# 4                  United States
# 6           United States, Japan

# %% [markdown]
# ### Adjusting income & budget based on realease year and inflation
# Why? Otherwise will newrealses have a bigger inpact on the model than older ones.
# Since the inflation isn´t linear, I found a librar called cpi, where you give year and amount and get back how much that would be in dollars in 2022(guess thats when the library is from and not yet updated but not a biggie for our model)

# %%
#loop through the rows in the dataset
for index, row in dataset_processed_1.iterrows():
    # calculate the budget with inflation included
    budget_inf = cpi.inflate(row['Budget'], row['Year'])
    # save the result in a new column named 'budget_inf'
    dataset_processed_1.at[index, 'budget_inf'] = budget_inf
    
    # calculate the income with inflation included
    income_inf = cpi.inflate(row['Income'], row['Year'])
    # save the result in a new column named 'income_inf'
    dataset_processed_1.at[index, 'income_inf'] = income_inf

# %%
dataset_processed_1.head(120)
# Out:
#                               Title  Rating  Year     Month Certificate  \
# 0          Avatar: The Way of Water     7.8  2022  December       PG-13
# 1    Guillermo del Toro's Pinocchio     7.6  2022  December          PG
# 2                      Bullet Train     7.3  2022    August           R
# 4                             M3gan     6.4  2022  December       PG-13
# 6                         Amsterdam     6.1  2022   October           R
# ..                              ...     ...   ...       ...         ...
# 247                       Nomadland     7.3  2020  February           R
# 248       The King of Staten Island     7.1  2020      June           R
# 254                        2 Hearts     6.3  2020   October       PG-13
# 255                       Bloodshot     5.7  2020     March       PG-13
# 258                       Greenland     6.4  2020  December       PG-13
#
#     Runtime                           Directors  \
# 0       192                       James Cameron
# 1       117  Guillermo del Toro, Mark Gustafson
# 2       127                        David Leitch
# 4       102                    Gerard Johnstone
# 6       134                     David O Russell
# ..      ...                                 ...
# 247     107                           Chlo Zhao
# 248     136                         Judd Apatow
# 254     101                          Lance Hool
# 255     109                         Dave Wilson
# 258     119                     Ric Roman Waugh
#
#                                                  Stars  \
# 0    Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1    Ewan McGregor, David Bradley, Gregory Mann, Bu...
# 2    Brad Pitt, Joey King, Aaron Taylor Johnson, Br...
# 4    Jenna Davis, Amie Donald, Allison Williams, Vi...
# 6    Christian Bale, Margot Robbie, John David Wash...
# ..                                                 ...
# 247  Frances McDormand, David Strathairn, Linda May...
# 248  Pete Davidson, Bel Powley, Ricky Velez, Lou Wi...
# 254  Jacob Elordi, Adan Canto, Tiera Skovbye, Radha...
# 255  Vin Diesel, Eiza Gonz lez, Sam Heughan, Toby K...
# 258  Gerard Butler, Morena Baccarin, Roger Dale Flo...
#
#                           Genre Filming_location       Budget        Income  \
# 0    Action, Adventure, Fantasy      New Zealand  350000000.0  2.267947e+09
# 1      Animation, Drama, Family              USA   35000000.0  1.089670e+05
# 2      Action, Comedy, Thriller            Japan   85900000.0  2.392686e+08
# 4      Horror, Sci-Fi, Thriller      New Zealand   12000000.0  1.712539e+08
# 6        Comedy, Drama, History              USA   80000000.0  3.124581e+07
# ..                          ...              ...          ...           ...
# 247                       Drama              USA    5000000.0  3.945821e+07
# 248               Comedy, Drama          Unknown   35000000.0  2.180452e+06
# 254              Drama, Romance           Canada   15000000.0  1.349286e+06
# 255   Action, Adventure, Sci-Fi           Canada   45000000.0  3.986112e+07
# 258            Action, Thriller          Iceland   34000000.0  5.230000e+07
#
#                  Country_of_origin    budget_inf    income_inf
# 0                    United States  3.500000e+08  2.267947e+09
# 1    United States, Mexico, France  3.500000e+07  1.089670e+05
# 2             Japan, United States  8.590000e+07  2.392686e+08
# 4                    United States  1.200000e+07  1.712539e+08
# 6             United States, Japan  8.000000e+07  3.124581e+07
# ..                             ...           ...           ...
# 247                  United States  5.653836e+06  4.461805e+07
# 248           United States, China  3.957685e+07  2.465584e+06
# 254                  United States  1.696151e+07  1.525728e+06
# 255                  United States  5.088453e+07  4.507365e+07
# 258  United States, United Kingdom  3.844609e+07  5.913913e+07
#
# [120 rows x 15 columns]

# %% [markdown]
# # Looking for outliers
# ### Look at ROI for the movies
# Return on investment

# %%
#loop through the rows in the dataset
for index, row in dataset_processed_1.iterrows():
    # calculate the roi in percentage
    roi_inf = ((row['income_inf'] - row['budget_inf']) / row['budget_inf']) * 100
    # save the result in a new column named 'budget_inf'
    dataset_processed_1.at[index, 'roi_inf'] = roi_inf

# %%
dataset_processed_1.head(120)
# Out:
#                               Title  Rating  Year     Month Certificate  \
# 0          Avatar: The Way of Water     7.8  2022  December       PG-13
# 1    Guillermo del Toro's Pinocchio     7.6  2022  December          PG
# 2                      Bullet Train     7.3  2022    August           R
# 4                             M3gan     6.4  2022  December       PG-13
# 6                         Amsterdam     6.1  2022   October           R
# ..                              ...     ...   ...       ...         ...
# 247                       Nomadland     7.3  2020  February           R
# 248       The King of Staten Island     7.1  2020      June           R
# 254                        2 Hearts     6.3  2020   October       PG-13
# 255                       Bloodshot     5.7  2020     March       PG-13
# 258                       Greenland     6.4  2020  December       PG-13
#
#     Runtime                           Directors  \
# 0       192                       James Cameron
# 1       117  Guillermo del Toro, Mark Gustafson
# 2       127                        David Leitch
# 4       102                    Gerard Johnstone
# 6       134                     David O Russell
# ..      ...                                 ...
# 247     107                           Chlo Zhao
# 248     136                         Judd Apatow
# 254     101                          Lance Hool
# 255     109                         Dave Wilson
# 258     119                     Ric Roman Waugh
#
#                                                  Stars  \
# 0    Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1    Ewan McGregor, David Bradley, Gregory Mann, Bu...
# 2    Brad Pitt, Joey King, Aaron Taylor Johnson, Br...
# 4    Jenna Davis, Amie Donald, Allison Williams, Vi...
# 6    Christian Bale, Margot Robbie, John David Wash...
# ..                                                 ...
# 247  Frances McDormand, David Strathairn, Linda May...
# 248  Pete Davidson, Bel Powley, Ricky Velez, Lou Wi...
# 254  Jacob Elordi, Adan Canto, Tiera Skovbye, Radha...
# 255  Vin Diesel, Eiza Gonz lez, Sam Heughan, Toby K...
# 258  Gerard Butler, Morena Baccarin, Roger Dale Flo...
#
#                           Genre Filming_location       Budget        Income  \
# 0    Action, Adventure, Fantasy      New Zealand  350000000.0  2.267947e+09
# 1      Animation, Drama, Family              USA   35000000.0  1.089670e+05
# 2      Action, Comedy, Thriller            Japan   85900000.0  2.392686e+08
# 4      Horror, Sci-Fi, Thriller      New Zealand   12000000.0  1.712539e+08
# 6        Comedy, Drama, History              USA   80000000.0  3.124581e+07
# ..                          ...              ...          ...           ...
# 247                       Drama              USA    5000000.0  3.945821e+07
# 248               Comedy, Drama          Unknown   35000000.0  2.180452e+06
# 254              Drama, Romance           Canada   15000000.0  1.349286e+06
# 255   Action, Adventure, Sci-Fi           Canada   45000000.0  3.986112e+07
# 258            Action, Thriller          Iceland   34000000.0  5.230000e+07
#
#                  Country_of_origin    budget_inf    income_inf      roi_inf
# 0                    United States  3.500000e+08  2.267947e+09   547.984852
# 1    United States, Mexico, France  3.500000e+07  1.089670e+05   -99.688666
# 2             Japan, United States  8.590000e+07  2.392686e+08   178.543192
# 4                    United States  1.200000e+07  1.712539e+08  1327.115917
# 6             United States, Japan  8.000000e+07  3.124581e+07   -60.942737
# ..                             ...           ...           ...          ...
# 247                  United States  5.653836e+06  4.461805e+07   689.164140
# 248           United States, China  3.957685e+07  2.465584e+06   -93.770137
# 254                  United States  1.696151e+07  1.525728e+06   -91.004760
# 255                  United States  5.088453e+07  4.507365e+07   -11.419738
# 258  United States, United Kingdom  3.844609e+07  5.913913e+07    53.823529
#
# [120 rows x 16 columns]

# %%
#Trying to find outliers in the data that can mess up the model
print(dataset_processed_1['roi_inf'].mean())
print(dataset_processed_1['roi_inf'].max())
print(dataset_processed_1['roi_inf'].min())
# Out:
# 11153.633623393485
# 16436555.231560891
# -99.975098

# %%
dataset_processed_2 = dataset_processed_1.sort_values(by='roi_inf', ascending=True)

# %%
dataset_processed_2.head(120)
# Out:
#                     Title  Rating  Year      Month Certificate Runtime  \
# 26              Pinocchio     5.1  2022  September          PG     105
# 59            White Noise     6.6  2022   December           R     136
# 1439  The Lazarus Project     6.1  2008       2008       PG-13     100
# 1366       Blood and Bone     6.7  2009  September           R      93
# 146            Red Notice     6.3  2021   November       PG-13     118
# ...                   ...     ...   ...        ...         ...     ...
# 49          Strange World     5.1  2022   November          PG     102
# 669               Silence     7.1  2016    January           R     161
# 886       Vampire Academy     5.4  2014   February       PG-13     104
# 1543          Funny Games     6.5  2007      April           R     111
# 589         Thoroughbreds     6.6  2017      March           R      92
#
#                     Directors  \
# 26            Robert Zemeckis
# 59              Noah Baumbach
# 1439               John Glenn
# 1366               Ben Ramsey
# 146   Rawson Marshall Thurber
# ...                       ...
# 49       Don Hall, Qui Nguyen
# 669           Martin Scorsese
# 886               Mark Waters
# 1543           Michael Haneke
# 589               Cory Finley
#
#                                                   Stars  \
# 26    Joseph Gordon Levitt, Tom Hanks, Benjamin Evan...
# 59    Adam Driver, Greta Gerwig, Don Cheadle, Madiso...
# 1439  Paul Walker, Piper Perabo, Brooklynn Proulx, B...
# 1366  Michael Jai White, Julian Sands, Eamonn Walker...
# 146   Dwayne Johnson, Ryan Reynolds, Gal Gadot, Ritu...
# ...                                                 ...
# 49    Jake Gyllenhaal, Jaboukie Young White, Gabriel...
# 669   Andrew Garfield, Adam Driver, Liam Neeson, Tad...
# 886   Zoey Deutch, Lucy Fry, Danila Kozlovskiy, Gabr...
# 1543  Naomi Watts, Tim Roth, Michael Pitt, Brady Corbet
# 589   Olivia Cooke, Anya Taylor Joy, Anton Yelchin, ...
#
#                              Genre Filming_location       Budget      Income  \
# 26        Adventure, Comedy, Drama            Italy  150000000.0     37353.0
# 59           Comedy, Drama, Horror              USA   80000000.0     70459.0
# 1439      Drama, Mystery, Thriller           Canada    9750000.0      9162.0
# 1366          Action, Crime, Drama              USA    3700000.0      3492.0
# 146       Action, Comedy, Thriller            Italy  160000000.0    178143.0
# ...                            ...              ...          ...         ...
# 49    Animation, Action, Adventure              USA  120000000.0  62170845.0
# 669                 Drama, History           Taiwan   46000000.0  23834809.0
# 886          Action, Comedy, Drama               UK   30000000.0  15642346.0
# 1543        Crime, Drama, Thriller              USA   15000000.0   7938872.0
# 589           Comedy, Crime, Drama              USA    6000000.0   3187255.0
#
#                                       Country_of_origin    budget_inf  \
# 26                                        United States  1.500000e+08
# 59                        United States, United Kingdom  8.000000e+07
# 1439              United States, Canada, United Kingdom  1.325289e+07
# 1366                                      United States  5.047258e+06
# 146                                       United States  1.728044e+08
# ...                                                 ...           ...
# 49                                        United States  1.200000e+08
# 669   United States, United Kingdom, Taiwan, Japan, ...  5.609057e+07
# 886                       United States, United Kingdom  3.708625e+07
# 1543  United States, France, United Kingdom, Austria...  2.117190e+07
# 589                                       United States  7.163553e+06
#
#         income_inf    roi_inf
# 26    3.735300e+04 -99.975098
# 59    7.045900e+04 -99.911926
# 1439  1.245364e+04 -99.906031
# 1366  4.763520e+03 -99.905622
# 146   1.923993e+05 -99.888661
# ...            ...        ...
# 49    6.217084e+07 -48.190963
# 669   2.906322e+07 -48.185198
# 886   1.933720e+07 -47.858847
# 1543  1.120540e+07 -47.074187
# 589   3.805345e+06 -46.879083
#
# [120 rows x 16 columns]

# %% [markdown]
# #  5 movies with the ROI of -99.9%
# Seems unlikely that the income-numbers are correct?

# %%
dataset_processed_2 = dataset_processed_1.sort_values(by='roi_inf', ascending=False)

# %%
dataset_processed_2.head(120)
# Out:
#                                    Title  Rating  Year      Month Certificate  \
# 487                            Trautmann     7.2  2018    October         NaN
# 1557                 Paranormal Activity     6.3  2007    October           R
# 1583                                Once     7.8  2007       June           R
# 627                           Your Name.     8.4  2016      April          PG
# 1811                   Napoleon Dynamite     6.9  2004     August          PG
# ...                                  ...     ...   ...        ...         ...
# 712   The VVitch: A New-England Folktale     6.9  2015   February           R
# 31                             Barbarian     7.1  2022  September           R
# 508                   The Shape of Water     7.3  2017   December           R
# 1917                        Finding Nemo     8.2  2003        May           G
# 732                      Pitch Perfect 2     6.4  2015        May       PG-13
#
#      Runtime                    Directors  \
# 487      120         Marcus H Rosenm ller
# 1557      86                    Oren Peli
# 1583      86                  John Carney
# 627      106               Makoto Shinkai
# 1811      96                   Jared Hess
# ...      ...                          ...
# 712       92                Robert Eggers
# 31       102                 Zach Cregger
# 508      123           Guillermo del Toro
# 1917     100  Andrew Stanton, Lee Unkrich
# 732      115              Elizabeth Banks
#
#                                                   Stars  \
# 487   David Kross, Freya Mavor, John Henshaw, Harry ...
# 1557  Katie Featherston, Micah Sloat, Mark Fredrichs...
# 1583  Glen Hansard, Mark ta Irglov , Hugh Walsh, Ger...
# 627   Ry nosuke Kamiki, Mone Kamishiraishi, Ry Narit...
# 1811   Jon Heder, Efren Ramirez, Jon Gries, Aaron Ruell
# ...                                                 ...
# 712   Anya Taylor Joy, Ralph Ineson, Kate Dickie, Ju...
# 31    Georgina Campbell, Bill Skarsg rd, Justin Long...
# 508   Sally Hawkins, Octavia Spencer, Michael Shanno...
# 1917  Albert Brooks, Ellen DeGeneres, Alexander Goul...
# 732   Anna Kendrick, Rebel Wilson, Hailee Steinfeld,...
#
#                              Genre  Filming_location       Budget  \
# 487      Biography, Drama, Romance  Northern Ireland        11.66
# 1557               Horror, Mystery               USA     15000.00
# 1583         Drama, Music, Romance           Ireland    150000.00
# 627      Animation, Drama, Fantasy           Unknown   2775000.00
# 1811                        Comedy               USA    400000.00
# ...                            ...               ...          ...
# 712         Drama, Fantasy, Horror            Canada   4000000.00
# 31       Horror, Mystery, Thriller          Bulgaria   4500000.00
# 508        Drama, Fantasy, Romance            Canada  19400000.00
# 1917  Animation, Adventure, Comedy               USA  94000000.00
# 732                  Comedy, Music               USA  29000000.00
#
#            Income                      Country_of_origin    budget_inf  \
# 487     1916514.0                United Kingdom, Germany  1.358926e+01
# 1557  193355800.0                          United States  2.117190e+04
# 1583   20936722.0                 Ireland, United States  2.117190e+05
# 627   358180115.0                                  Japan  3.383725e+06
# 1811   46138887.0                          United States  6.197035e+05
# ...           ...                                    ...           ...
# 712    40423945.0  United States, Canada, United Kingdom  4.938971e+06
# 31     45352337.0                          United States  4.500000e+06
# 508   195333312.0                  United States, Mexico  2.316215e+07
# 1917  940352645.0                          United States  1.495085e+08
# 732   287144079.0                          United States  3.580754e+07
#
#         income_inf       roi_inf
# 487   2.233619e+06  1.643656e+07
# 1557  2.729140e+08  1.288939e+06
# 1583  2.955135e+07  1.385781e+04
# 627   4.367506e+08  1.280739e+04
# 1811  7.148108e+07  1.143472e+04
# ...            ...           ...
# 712   4.991317e+07  9.105986e+02
# 31    4.535234e+07  9.078297e+02
# 508   2.332134e+08  9.068727e+02
# 1917  1.495646e+09  9.003752e+02
# 732   3.545490e+08  8.901520e+02
#
# [120 rows x 16 columns]

# %% [markdown]
# #  2 movies with strange budgets
# number1, budget of $11 obv wrong in dataset
#
# number2, Paranormal Activity, accordingly had a budget of $15k, which is superunlikely

# %% [markdown]
# Suggest solution:
# Remove roi-outliers by filtering budgets & Roi
# budget -min 100 000 $ (no reason to have uperlimit, movies can cost endless of money)
# roi -min -95% (rather inspect dataset and look for weird stuff than set an upperlimit, since a movie can generate tons and tons of movie.)

# %%
##dataset_processed_outliers_roi = dataset_processed_outliers_roi[dataset_processed_2['roi_inf'] > -95]
