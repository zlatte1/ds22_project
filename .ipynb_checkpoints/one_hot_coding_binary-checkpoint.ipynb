# %%
import pandas as pd

# %%
dataset_raw = pd.read_csv('C:/Users/admin1/Documents/GitHub/ds22_project/data/movies.csv')
dataset_raw.head(2)
# Out:
#                             Title  Rating  Year     Month Certificate Runtime  \
# 0        Avatar: The Way of Water     7.8  2022  December       PG-13     192
# 1  Guillermo del Toro's Pinocchio     7.6  2022  December          PG     117
#
#                             Directors  \
# 0                       James Cameron
# 1  Guillermo del Toro, Mark Gustafson
#
#                                                Stars  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1  Ewan McGregor, David Bradley, Gregory Mann, Bu...
#
#                         Genre Filming_location         Budget  \
# 0  Action, Adventure, Fantasy      New Zealand  $350,000,000
# 1    Animation, Drama, Family              USA   $35,000,000
#
#             Income              Country_of_origin
# 0  $2,267,946,983                   United States
# 1        $108,967   United States, Mexico, France

# %%
import pandas as pd

def one_hot_encoding_binary(dataset, orginal_column, new_column_name, file_location, file_column="Name", separator=",", process_all_names=False):
    # 1. Splitting the original column based on the separator
    split_values = dataset[orginal_column].str.split(separator)

    # 2. Selecting only the first or all names based on the 'process_all_names' argument
    if process_all_names:
        values_to_process = split_values
    else:
        values_to_process = split_values.str[0]

    # 3. Creating the new column with binary values
    dataset[new_column_name] = values_to_process.isin(pd.read_csv(file_location)[file_column]).astype(int)

    # 4. Dropping the original column
    dataset.drop(columns=[orginal_column], inplace=True)

    # 5. Check the updated table
    #dataset.head(2)
    return dataset

# %%
dataset_prosscessed = one_hot_encoding_binary(dataset_raw, "Directors", "Top_50_Director", "C:/Users/admin1/Documents/GitHub/ds22_project/data/top_1000_actors.csv")

# %%
dataset_prosscessed.head()
# Out:
#                             Title  Rating  Year     Month Certificate Runtime  \
# 0        Avatar: The Way of Water     7.8  2022  December       PG-13     192
# 1  Guillermo del Toro's Pinocchio     7.6  2022  December          PG     117
# 2                    Bullet Train     7.3  2022    August           R     127
# 3       The Banshees of Inisherin     7.8  2022  November           R     114
# 4                           M3gan     6.4  2022  December       PG-13     102
#
#                                                Stars  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver...
# 1  Ewan McGregor, David Bradley, Gregory Mann, Bu...
# 2  Brad Pitt, Joey King, Aaron Taylor Johnson, Br...
# 3  Colin Farrell, Brendan Gleeson, Kerry Condon, ...
# 4  Jenna Davis, Amie Donald, Allison Williams, Vi...
#
#                         Genre Filming_location         Budget  \
# 0  Action, Adventure, Fantasy      New Zealand  $350,000,000
# ...

# %%
dataset_prosscessed.to_csv('C:/zlatte1/222222.csv', index=False)

# %%
dataset_prosscessed.info()

# %%
count_positive = (dataset_prosscessed['Top_50_Director'] > 0).sum()

# Print the count of positive values
print(count_positive)
